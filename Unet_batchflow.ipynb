# %%
import torch
from batchflow.models.torch import TorchModel
from batchflow.models.torch import ResNet, EncoderDecoder
from batchflow.models.torch.layers import ConvBlock

# %%
downsample_depth = 4
in_channels = 3
config = {
    'inputs/images/shape': (in_channels, 32, 32), # can be commented
    'initial_block/inputs': 'images', # can be commented    
    'device': 'gpu:0',

    'body/encoder': {
        'num_stages': downsample_depth,
        'order': ['skip', 'block', 'downsampling']
    },    
    'body/encoder/blocks': {
        'layout': 'cna cna',
        'filters': [in_channels*pow(2, i) for i in range(1, downsample_depth+1)]
    },
    'body/encoder/downsample': {
        'layout': 'p'
    },    
    
    'body/embedding': {
        'layout': 'cna cna', 
        'filters': in_channels*pow(2, downsample_depth)
    },   

    'body/decoder': {
        'num_stages': downsample_depth,
        'order': ['upsampling', 'combine', 'block'] # check        
    },
    'body/decoder/upsample': {
        'layout': 't',
        'filters': [in_channels*pow(2, i-1) for i in range(downsample_depth, -1, -1)]
    },
    'body/decoder/combine': {
        'op': 'concat',
        'leading_index': 1
    },
    'body/decoder/blocks': {
        'layout': 'cna cna',
        'filters': [in_channels*pow(2, i-1) for i in range(downsample_depth, -1, -1)]
    },
    'head':{
        'layout': 'ca',
        'filters': in_channels,
        'activation': 'Softmax'
    },
    
    'loss': 'mse',
    'optimizer': 'Adam'
}

model = EncoderDecoder(config)
# Out:
# /notebooks/sorokina/batchflow/batchflow/models/torch/layers/core.py:85: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.activation(x, *self.args, **self.kwargs)

# %%
model.short_repr()
# Out:
# Sequential(
#   (body): Sequential(
#     (encoder): EncoderModule(
#       (skip-0): Identity()
#       (block-0): ConvBlock
#       DefaultBlock
#         layout=cnacna
#           Layer 0,  letter "c": (None, 3, 32, 32) -> (None, 6, 32, 32)
#           Layer 1,  letter "n": (None, 6, 32, 32) -> (None, 6, 32, 32)
#           Layer 2,  letter "a": (None, 6, 32, 32) -> (None, 6, 32, 32)
#           Layer 3,  letter "c": (None, 6, 32, 32) -> (None, 6, 32, 32)
#           Layer 4,  letter "n": (None, 6, 32, 32) -> (None, 6, 32, 32)
#           Layer 5,  letter "a": (None, 6, 32, 32) -> (None, 6, 32, 32)
#
#       (downsample-0): ConvBlock
#       layout=p
#         Layer 0,  letter "p": (None, 6, 32, 32) -> (None, 6, 16, 16)
#
#       (skip-1): Identity()
#       (block-1): ConvBlock
#       DefaultBlock
#         layout=cnacna
#           Layer 0,  letter "c": (None, 6, 16, 16) -> (None, 12, 16, 16)
#           Layer 1,  letter "n": (None, 12, 16, 16) -> (None, 12, 16, 16)
#           Layer 2,  letter "a": (None, 12, 16, 16) -> (None, 12, 16, 16)
#           Layer 3,  letter "c": (None, 12, 16, 16) -> (None, 12, 16, 16)
#           Layer 4,  letter "n": (None, 12, 16, 16) -> (None, 12, 16, 16)
#           Layer 5,  letter "a": (None, 12, 16, 16) -> (None, 12, 16, 16)
#
#       (downsample-1): ConvBlock
#       layout=p
#         Layer 0,  letter "p": (None, 12, 16, 16) -> (None, 12, 8, 8)
#
#       (skip-2): Identity()
#       (block-2): ConvBlock
#       DefaultBlock
#         layout=cnacna
#           Layer 0,  letter "c": (None, 12, 8, 8) -> (None, 24, 8, 8)
#           Layer 1,  letter "n": (None, 24, 8, 8) -> (None, 24, 8, 8)
#           Layer 2,  letter "a": (None, 24, 8, 8) -> (None, 24, 8, 8)
#           Layer 3,  letter "c": (None, 24, 8, 8) -> (None, 24, 8, 8)
#           Layer 4,  letter "n": (None, 24, 8, 8) -> (None, 24, 8, 8)
#           Layer 5,  letter "a": (None, 24, 8, 8) -> (None, 24, 8, 8)
#
#       (downsample-2): ConvBlock
#       layout=p
#         Layer 0,  letter "p": (None, 24, 8, 8) -> (None, 24, 4, 4)
#
#       (skip-3): Identity()
#       (block-3): ConvBlock
#       DefaultBlock
#         layout=cnacna
#           Layer 0,  letter "c": (None, 24, 4, 4) -> (None, 48, 4, 4)
#           Layer 1,  letter "n": (None, 48, 4, 4) -> (None, 48, 4, 4)
#           Layer 2,  letter "a": (None, 48, 4, 4) -> (None, 48, 4, 4)
#           Layer 3,  letter "c": (None, 48, 4, 4) -> (None, 48, 4, 4)
#           Layer 4,  letter "n": (None, 48, 4, 4) -> (None, 48, 4, 4)
#           Layer 5,  letter "a": (None, 48, 4, 4) -> (None, 48, 4, 4)
#
#       (downsample-3): ConvBlock
#       layout=p
#         Layer 0,  letter "p": (None, 48, 4, 4) -> (None, 48, 2, 2)
#
#     )
#     (embedding): EmbeddingModule(
#       (embedding): ConvBlock
#       DefaultBlock
#         layout=cnacna
#           Layer 0,  letter "c": (None, 48, 2, 2) -> (None, 48, 2, 2)
#           Layer 1,  letter "n": (None, 48, 2, 2) -> (None, 48, 2, 2)
#           Layer 2,  letter "a": (None, 48, 2, 2) -> (None, 48, 2, 2)
#           Layer 3,  letter "c": (None, 48, 2, 2) -> (None, 48, 2, 2)
#           Layer 4,  letter "n": (None, 48, 2, 2) -> (None, 48, 2, 2)
#           Layer 5,  letter "a": (None, 48, 2, 2) -> (None, 48, 2, 2)
#
#     )
#     (decoder): DecoderModule(
#       (upsample-0): Upsample(
#         (layer): ConvBlock
#         layout=t
#           Layer 0,  letter "t": (None, 48, 2, 2) -> (None, 24, 4, 4)
#
#       )
#       (combine-0): Combine(
#         op=concat,
#         leading_idx=1,
#         input_shapes=[[(2, 24, 4, 4), (2, 24, 4, 4)]],
#         resized_shapes=[[(2, 24, 4, 4), (2, 24, 4, 4)]],
#         output_shape=(2, 48, 4, 4)
#       )
#       (block-0): ConvBlock
#       DefaultBlock
#         layout=cnacna
#           Layer 0,  letter "c": (None, 48, 4, 4) -> (None, 24, 4, 4)
#           Layer 1,  letter "n": (None, 24, 4, 4) -> (None, 24, 4, 4)
#           Layer 2,  letter "a": (None, 24, 4, 4) -> (None, 24, 4, 4)
#           Layer 3,  letter "c": (None, 24, 4, 4) -> (None, 24, 4, 4)
#           Layer 4,  letter "n": (None, 24, 4, 4) -> (None, 24, 4, 4)
#           Layer 5,  letter "a": (None, 24, 4, 4) -> (None, 24, 4, 4)
#
#       (upsample-1): Upsample(
#         (layer): ConvBlock
#         layout=t
#           Layer 0,  letter "t": (None, 24, 4, 4) -> (None, 12, 8, 8)
#
#       )
#       (combine-1): Combine(
#         op=concat,
#         leading_idx=1,
#         input_shapes=[[(2, 12, 8, 8), (2, 12, 8, 8)]],
#         resized_shapes=[[(2, 12, 8, 8), (2, 12, 8, 8)]],
#         output_shape=(2, 24, 8, 8)
#       )
#       (block-1): ConvBlock
#       DefaultBlock
#         layout=cnacna
#           Layer 0,  letter "c": (None, 24, 8, 8) -> (None, 12, 8, 8)
#           Layer 1,  letter "n": (None, 12, 8, 8) -> (None, 12, 8, 8)
#           Layer 2,  letter "a": (None, 12, 8, 8) -> (None, 12, 8, 8)
#           Layer 3,  letter "c": (None, 12, 8, 8) -> (None, 12, 8, 8)
#           Layer 4,  letter "n": (None, 12, 8, 8) -> (None, 12, 8, 8)
#           Layer 5,  letter "a": (None, 12, 8, 8) -> (None, 12, 8, 8)
#
#       (upsample-2): Upsample(
#         (layer): ConvBlock
#         layout=t
#           Layer 0,  letter "t": (None, 12, 8, 8) -> (None, 6, 16, 16)
#
#       )
#       (combine-2): Combine(
#         op=concat,
#         leading_idx=1,
#         input_shapes=[[(2, 6, 16, 16), (2, 6, 16, 16)]],
#         resized_shapes=[[(2, 6, 16, 16), (2, 6, 16, 16)]],
#         output_shape=(2, 12, 16, 16)
#       )
#       (block-2): ConvBlock
#       DefaultBlock
#         layout=cnacna
#           Layer 0,  letter "c": (None, 12, 16, 16) -> (None, 6, 16, 16)
#           Layer 1,  letter "n": (None, 6, 16, 16) -> (None, 6, 16, 16)
#           Layer 2,  letter "a": (None, 6, 16, 16) -> (None, 6, 16, 16)
#           Layer 3,  letter "c": (None, 6, 16, 16) -> (None, 6, 16, 16)
#           Layer 4,  letter "n": (None, 6, 16, 16) -> (None, 6, 16, 16)
#           Layer 5,  letter "a": (None, 6, 16, 16) -> (None, 6, 16, 16)
#
#       (upsample-3): Upsample(
#         (layer): ConvBlock
#         layout=t
#           Layer 0,  letter "t": (None, 6, 16, 16) -> (None, 3, 32, 32)
#
#       )
#       (combine-3): Combine(
#         op=concat,
#         leading_idx=1,
#         input_shapes=[[(2, 3, 32, 32), (2, 3, 32, 32)]],
#         resized_shapes=[[(2, 3, 32, 32), (2, 3, 32, 32)]],
#         output_shape=(2, 6, 32, 32)
#       )
#       (block-3): ConvBlock
#       DefaultBlock
#         layout=cnacna
#           Layer 0,  letter "c": (None, 6, 32, 32) -> (None, 3, 32, 32)
#           Layer 1,  letter "n": (None, 3, 32, 32) -> (None, 3, 32, 32)
#           Layer 2,  letter "a": (None, 3, 32, 32) -> (None, 3, 32, 32)
#           Layer 3,  letter "c": (None, 3, 32, 32) -> (None, 3, 32, 32)
#           Layer 4,  letter "n": (None, 3, 32, 32) -> (None, 3, 32, 32)
#           Layer 5,  letter "a": (None, 3, 32, 32) -> (None, 3, 32, 32)
#
#     )
#   )
#   (head): Sequential(
#     (0): ConvBlock
#     layout=ca
#       Layer 0,  letter "c": (None, 3, 32, 32) -> (None, 3, 32, 32)
#       Layer 1,  letter "a": (None, 3, 32, 32) -> (None, 3, 32, 32)
#
#   )
# )

# %%
model.model
# Out:
# Sequential(
#   (body): Sequential(
#     (encoder): EncoderModule(
#       (skip-0): Identity()
#       (block-0): ConvBlock(
#         (0): DefaultBlock(
#           (0): BaseConvBlock(
#             layout=cnacna
#
#             (Layer 0,  letter "c": (None, 3, 32, 32) -> (None, 6, 32, 32)): Conv(
#               (layer): Conv2d(3, 6, kernel_size=(3, 3), stride=(1, 1), bias=False)
#             )
#             (Layer 1,  letter "n": (None, 6, 32, 32) -> (None, 6, 32, 32)): BatchNorm(
#               (layer): BatchNorm2d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (Layer 2,  letter "a": (None, 6, 32, 32) -> (None, 6, 32, 32)): Activation(
#               (activation): ReLU(inplace=True)
#             )
#             (Layer 3,  letter "c": (None, 6, 32, 32) -> (None, 6, 32, 32)): Conv(
#               (layer): Conv2d(6, 6, kernel_size=(3, 3), stride=(1, 1), bias=False)
#             )
#             (Layer 4,  letter "n": (None, 6, 32, 32) -> (None, 6, 32, 32)): BatchNorm(
#               (layer): BatchNorm2d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (Layer 5,  letter "a": (None, 6, 32, 32) -> (None, 6, 32, 32)): Activation(
#               (activation): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#       (downsample-0): ConvBlock(
#         (0): BaseConvBlock(
#           layout=p
#
#           (Layer 0,  letter "p": (None, 6, 32, 32) -> (None, 6, 16, 16)): Pool(
#             (pool): MaxPool(
#               (layer): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#             )
#           )
#         )
#       )
#       (skip-1): Identity()
#       (block-1): ConvBlock(
#         (0): DefaultBlock(
#           (0): BaseConvBlock(
#             layout=cnacna
#
#             (Layer 0,  letter "c": (None, 6, 16, 16) -> (None, 12, 16, 16)): Conv(
#               (layer): Conv2d(6, 12, kernel_size=(3, 3), stride=(1, 1), bias=False)
#             )
#             (Layer 1,  letter "n": (None, 12, 16, 16) -> (None, 12, 16, 16)): BatchNorm(
#               (layer): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (Layer 2,  letter "a": (None, 12, 16, 16) -> (None, 12, 16, 16)): Activation(
#               (activation): ReLU(inplace=True)
#             )
#             (Layer 3,  letter "c": (None, 12, 16, 16) -> (None, 12, 16, 16)): Conv(
#               (layer): Conv2d(12, 12, kernel_size=(3, 3), stride=(1, 1), bias=False)
#             )
#             (Layer 4,  letter "n": (None, 12, 16, 16) -> (None, 12, 16, 16)): BatchNorm(
#               (layer): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (Layer 5,  letter "a": (None, 12, 16, 16) -> (None, 12, 16, 16)): Activation(
#               (activation): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#       (downsample-1): ConvBlock(
#         (0): BaseConvBlock(
#           layout=p
#
#           (Layer 0,  letter "p": (None, 12, 16, 16) -> (None, 12, 8, 8)): Pool(
#             (pool): MaxPool(
#               (layer): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#             )
#           )
#         )
#       )
#       (skip-2): Identity()
#       (block-2): ConvBlock(
#         (0): DefaultBlock(
#           (0): BaseConvBlock(
#             layout=cnacna
#
#             (Layer 0,  letter "c": (None, 12, 8, 8) -> (None, 24, 8, 8)): Conv(
#               (layer): Conv2d(12, 24, kernel_size=(3, 3), stride=(1, 1), bias=False)
#             )
#             (Layer 1,  letter "n": (None, 24, 8, 8) -> (None, 24, 8, 8)): BatchNorm(
#               (layer): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (Layer 2,  letter "a": (None, 24, 8, 8) -> (None, 24, 8, 8)): Activation(
#               (activation): ReLU(inplace=True)
#             )
#             (Layer 3,  letter "c": (None, 24, 8, 8) -> (None, 24, 8, 8)): Conv(
#               (layer): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), bias=False)
#             )
#             (Layer 4,  letter "n": (None, 24, 8, 8) -> (None, 24, 8, 8)): BatchNorm(
#               (layer): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (Layer 5,  letter "a": (None, 24, 8, 8) -> (None, 24, 8, 8)): Activation(
#               (activation): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#       (downsample-2): ConvBlock(
#         (0): BaseConvBlock(
#           layout=p
#
#           (Layer 0,  letter "p": (None, 24, 8, 8) -> (None, 24, 4, 4)): Pool(
#             (pool): MaxPool(
#               (layer): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#             )
#           )
#         )
#       )
#       (skip-3): Identity()
#       (block-3): ConvBlock(
#         (0): DefaultBlock(
#           (0): BaseConvBlock(
#             layout=cnacna
#
#             (Layer 0,  letter "c": (None, 24, 4, 4) -> (None, 48, 4, 4)): Conv(
#               (layer): Conv2d(24, 48, kernel_size=(3, 3), stride=(1, 1), bias=False)
#             )
#             (Layer 1,  letter "n": (None, 48, 4, 4) -> (None, 48, 4, 4)): BatchNorm(
#               (layer): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (Layer 2,  letter "a": (None, 48, 4, 4) -> (None, 48, 4, 4)): Activation(
#               (activation): ReLU(inplace=True)
#             )
#             (Layer 3,  letter "c": (None, 48, 4, 4) -> (None, 48, 4, 4)): Conv(
#               (layer): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), bias=False)
#             )
#             (Layer 4,  letter "n": (None, 48, 4, 4) -> (None, 48, 4, 4)): BatchNorm(
#               (layer): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (Layer 5,  letter "a": (None, 48, 4, 4) -> (None, 48, 4, 4)): Activation(
#               (activation): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#       (downsample-3): ConvBlock(
#         (0): BaseConvBlock(
#           layout=p
#
#           (Layer 0,  letter "p": (None, 48, 4, 4) -> (None, 48, 2, 2)): Pool(
#             (pool): MaxPool(
#               (layer): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#             )
#           )
#         )
#       )
#     )
#     (embedding): EmbeddingModule(
#       (embedding): ConvBlock(
#         (0): DefaultBlock(
#           (0): BaseConvBlock(
#             layout=cnacna
#
#             (Layer 0,  letter "c": (None, 48, 2, 2) -> (None, 48, 2, 2)): Conv(
#               (layer): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), bias=False)
#             )
#             (Layer 1,  letter "n": (None, 48, 2, 2) -> (None, 48, 2, 2)): BatchNorm(
#               (layer): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (Layer 2,  letter "a": (None, 48, 2, 2) -> (None, 48, 2, 2)): Activation(
#               (activation): ReLU(inplace=True)
#             )
#             (Layer 3,  letter "c": (None, 48, 2, 2) -> (None, 48, 2, 2)): Conv(
#               (layer): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), bias=False)
#             )
#             (Layer 4,  letter "n": (None, 48, 2, 2) -> (None, 48, 2, 2)): BatchNorm(
#               (layer): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (Layer 5,  letter "a": (None, 48, 2, 2) -> (None, 48, 2, 2)): Activation(
#               (activation): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#     )
#     (decoder): DecoderModule(
#       (upsample-0): Upsample(
#         (layer): ConvBlock(
#           (0): BaseConvBlock(
#             layout=t
#
#             (Layer 0,  letter "t": (None, 48, 2, 2) -> (None, 24, 4, 4)): ConvTranspose(
#               (layer): ConvTranspose2d(48, 24, kernel_size=(2, 2), stride=(2, 2), bias=False)
#             )
#           )
#         )
#       )
#       (combine-0): Combine(
#         op=concat,
#         leading_idx=1,
#         input_shapes=[[(2, 24, 4, 4), (2, 24, 4, 4)]],
#         resized_shapes=[[(2, 24, 4, 4), (2, 24, 4, 4)]],
#         output_shape=(2, 48, 4, 4)
#       )
#       (block-0): ConvBlock(
#         (0): DefaultBlock(
#           (0): BaseConvBlock(
#             layout=cnacna
#
#             (Layer 0,  letter "c": (None, 48, 4, 4) -> (None, 24, 4, 4)): Conv(
#               (layer): Conv2d(48, 24, kernel_size=(3, 3), stride=(1, 1), bias=False)
#             )
#             (Layer 1,  letter "n": (None, 24, 4, 4) -> (None, 24, 4, 4)): BatchNorm(
#               (layer): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (Layer 2,  letter "a": (None, 24, 4, 4) -> (None, 24, 4, 4)): Activation(
#               (activation): ReLU(inplace=True)
#             )
#             (Layer 3,  letter "c": (None, 24, 4, 4) -> (None, 24, 4, 4)): Conv(
#               (layer): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), bias=False)
#             )
#             (Layer 4,  letter "n": (None, 24, 4, 4) -> (None, 24, 4, 4)): BatchNorm(
#               (layer): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (Layer 5,  letter "a": (None, 24, 4, 4) -> (None, 24, 4, 4)): Activation(
#               (activation): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#       (upsample-1): Upsample(
#         (layer): ConvBlock(
#           (0): BaseConvBlock(
#             layout=t
#
#             (Layer 0,  letter "t": (None, 24, 4, 4) -> (None, 12, 8, 8)): ConvTranspose(
#               (layer): ConvTranspose2d(24, 12, kernel_size=(2, 2), stride=(2, 2), bias=False)
#             )
#           )
#         )
#       )
#       (combine-1): Combine(
#         op=concat,
#         leading_idx=1,
#         input_shapes=[[(2, 12, 8, 8), (2, 12, 8, 8)]],
#         resized_shapes=[[(2, 12, 8, 8), (2, 12, 8, 8)]],
#         output_shape=(2, 24, 8, 8)
#       )
#       (block-1): ConvBlock(
#         (0): DefaultBlock(
#           (0): BaseConvBlock(
#             layout=cnacna
#
#             (Layer 0,  letter "c": (None, 24, 8, 8) -> (None, 12, 8, 8)): Conv(
#               (layer): Conv2d(24, 12, kernel_size=(3, 3), stride=(1, 1), bias=False)
#             )
#             (Layer 1,  letter "n": (None, 12, 8, 8) -> (None, 12, 8, 8)): BatchNorm(
#               (layer): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (Layer 2,  letter "a": (None, 12, 8, 8) -> (None, 12, 8, 8)): Activation(
#               (activation): ReLU(inplace=True)
#             )
#             (Layer 3,  letter "c": (None, 12, 8, 8) -> (None, 12, 8, 8)): Conv(
#               (layer): Conv2d(12, 12, kernel_size=(3, 3), stride=(1, 1), bias=False)
#             )
#             (Layer 4,  letter "n": (None, 12, 8, 8) -> (None, 12, 8, 8)): BatchNorm(
#               (layer): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (Layer 5,  letter "a": (None, 12, 8, 8) -> (None, 12, 8, 8)): Activation(
#               (activation): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#       (upsample-2): Upsample(
#         (layer): ConvBlock(
#           (0): BaseConvBlock(
#             layout=t
#
#             (Layer 0,  letter "t": (None, 12, 8, 8) -> (None, 6, 16, 16)): ConvTranspose(
#               (layer): ConvTranspose2d(12, 6, kernel_size=(2, 2), stride=(2, 2), bias=False)
#             )
#           )
#         )
#       )
#       (combine-2): Combine(
#         op=concat,
#         leading_idx=1,
#         input_shapes=[[(2, 6, 16, 16), (2, 6, 16, 16)]],
#         resized_shapes=[[(2, 6, 16, 16), (2, 6, 16, 16)]],
#         output_shape=(2, 12, 16, 16)
#       )
#       (block-2): ConvBlock(
#         (0): DefaultBlock(
#           (0): BaseConvBlock(
#             layout=cnacna
#
#             (Layer 0,  letter "c": (None, 12, 16, 16) -> (None, 6, 16, 16)): Conv(
#               (layer): Conv2d(12, 6, kernel_size=(3, 3), stride=(1, 1), bias=False)
#             )
#             (Layer 1,  letter "n": (None, 6, 16, 16) -> (None, 6, 16, 16)): BatchNorm(
#               (layer): BatchNorm2d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (Layer 2,  letter "a": (None, 6, 16, 16) -> (None, 6, 16, 16)): Activation(
#               (activation): ReLU(inplace=True)
#             )
#             (Layer 3,  letter "c": (None, 6, 16, 16) -> (None, 6, 16, 16)): Conv(
#               (layer): Conv2d(6, 6, kernel_size=(3, 3), stride=(1, 1), bias=False)
#             )
#             (Layer 4,  letter "n": (None, 6, 16, 16) -> (None, 6, 16, 16)): BatchNorm(
#               (layer): BatchNorm2d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (Layer 5,  letter "a": (None, 6, 16, 16) -> (None, 6, 16, 16)): Activation(
#               (activation): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#       (upsample-3): Upsample(
#         (layer): ConvBlock(
#           (0): BaseConvBlock(
#             layout=t
#
#             (Layer 0,  letter "t": (None, 6, 16, 16) -> (None, 3, 32, 32)): ConvTranspose(
#               (layer): ConvTranspose2d(6, 3, kernel_size=(2, 2), stride=(2, 2), bias=False)
#             )
#           )
#         )
#       )
#       (combine-3): Combine(
#         op=concat,
#         leading_idx=1,
#         input_shapes=[[(2, 3, 32, 32), (2, 3, 32, 32)]],
#         resized_shapes=[[(2, 3, 32, 32), (2, 3, 32, 32)]],
#         output_shape=(2, 6, 32, 32)
#       )
#       (block-3): ConvBlock(
#         (0): DefaultBlock(
#           (0): BaseConvBlock(
#             layout=cnacna
#
#             (Layer 0,  letter "c": (None, 6, 32, 32) -> (None, 3, 32, 32)): Conv(
#               (layer): Conv2d(6, 3, kernel_size=(3, 3), stride=(1, 1), bias=False)
#             )
#             (Layer 1,  letter "n": (None, 3, 32, 32) -> (None, 3, 32, 32)): BatchNorm(
#               (layer): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (Layer 2,  letter "a": (None, 3, 32, 32) -> (None, 3, 32, 32)): Activation(
#               (activation): ReLU(inplace=True)
#             )
#             (Layer 3,  letter "c": (None, 3, 32, 32) -> (None, 3, 32, 32)): Conv(
#               (layer): Conv2d(3, 3, kernel_size=(3, 3), stride=(1, 1), bias=False)
#             )
#             (Layer 4,  letter "n": (None, 3, 32, 32) -> (None, 3, 32, 32)): BatchNorm(
#               (layer): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (Layer 5,  letter "a": (None, 3, 32, 32) -> (None, 3, 32, 32)): Activation(
#               (activation): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#     )
#   )
#   (head): Sequential(
#     (0): ConvBlock(
#       (0): BaseConvBlock(
#         layout=ca
#
#         (Layer 0,  letter "c": (None, 3, 32, 32) -> (None, 3, 32, 32)): Conv(
#           (layer): Conv2d(3, 3, kernel_size=(3, 3), stride=(1, 1), bias=False)
#         )
#         (Layer 1,  letter "a": (None, 3, 32, 32) -> (None, 3, 32, 32)): Activation(
#           (activation): Softmax(dim=None)
#         )
#       )
#     )
#   )
# )
