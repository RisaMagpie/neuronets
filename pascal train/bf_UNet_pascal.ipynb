# %%
# %env CUDA_VISIBLE_DEVICES=3
# Out:
# env: CUDA_VISIBLE_DEVICES=3

# %%
import torch
from torch import nn
import torch.optim as optim
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
from tqdm.auto import tqdm
from batchflow import Pipeline, B, C, D, F, V, W
from batchflow.models.torch import EncoderDecoder, UNet
from batchflow.models.torch.layers import ConvBlock
from batchflow.models.torch.layers.modules import ASPP
from batchflow.opensets import PascalSegmentation

# %%
dataset = PascalSegmentation(bar='n')

# %%
in_channels = 3
out_channels = 3

batch_size = 64
epoch_num = 5

IMAGE_SHAPE = (160, 160)

# %%
downsample_depth = 4
in_channels = 3
num_classes = 22
# https://github.com/tks10/segmentation_unet

model_config = {
    'inputs/images/shape': (in_channels, 160, 160), # can be commented
    'initial_block/inputs': 'images', # can be commented    

    'body/encoder': {
        'num_stages': downsample_depth,
        'order': ['skip', 'block', 'downsampling']
    },    
    'body/encoder/blocks': {
        'layout': 'cna cna',
        'filters': [in_channels*pow(2, i) for i in range(1, downsample_depth+1)]
    },
    'body/encoder/downsample': {
        'layout': 'p'
    },    
    
    'body/embedding': {
        'layout': 'cna cna', 
        'filters': [2*in_channels*pow(2, downsample_depth), in_channels*pow(2, downsample_depth)]
    },   

    'body/decoder': {
        'num_stages': downsample_depth,
        'order': ['upsampling', 'combine', 'block']
    },
    'body/decoder/upsample': {
        'layout': 'tna',
        'filters': [in_channels*pow(2, i-1) for i in range(downsample_depth, -1, -1)]
    },
    'body/decoder/combine': {
        'op': 'concat'
    },
    'body/decoder/blocks': {
        'layout': 'cna cna',
        'filters': [in_channels*pow(2, i-1) for i in range(downsample_depth, -1, -1)]
    },

    'head':{
        'layout': 'c',#a',
        'filters': num_classes,
        #'activation': 'softmax',
        'kernel_size': 1
    },
    
    'loss': 'ce',
    'optimizer': 'Adam'
}

# %%
model = EncoderDecoder(model_config)

# %%
model.short_repr()
# Out:
# Sequential(
#   (body): Sequential(
#     (encoder): EncoderModule(
#       (skip-0): Identity()
#       (block-0): ConvBlock
#       DefaultBlock
#         layout=cnacna
#           Layer 0,  letter "c": (None, 3, 160, 160) -> (None, 6, 160, 160)
#           Layer 1,  letter "n": (None, 6, 160, 160) -> (None, 6, 160, 160)
#           Layer 2,  letter "a": (None, 6, 160, 160) -> (None, 6, 160, 160)
#           Layer 3,  letter "c": (None, 6, 160, 160) -> (None, 6, 160, 160)
#           Layer 4,  letter "n": (None, 6, 160, 160) -> (None, 6, 160, 160)
#           Layer 5,  letter "a": (None, 6, 160, 160) -> (None, 6, 160, 160)
#
#       (downsample-0): ConvBlock
#       layout=p
#         Layer 0,  letter "p": (None, 6, 160, 160) -> (None, 6, 80, 80)
#
#       (skip-1): Identity()
#       (block-1): ConvBlock
#       DefaultBlock
#         layout=cnacna
#           Layer 0,  letter "c": (None, 6, 80, 80) -> (None, 12, 80, 80)
#           Layer 1,  letter "n": (None, 12, 80, 80) -> (None, 12, 80, 80)
#           Layer 2,  letter "a": (None, 12, 80, 80) -> (None, 12, 80, 80)
#           Layer 3,  letter "c": (None, 12, 80, 80) -> (None, 12, 80, 80)
#           Layer 4,  letter "n": (None, 12, 80, 80) -> (None, 12, 80, 80)
#           Layer 5,  letter "a": (None, 12, 80, 80) -> (None, 12, 80, 80)
#
#       (downsample-1): ConvBlock
#       layout=p
#         Layer 0,  letter "p": (None, 12, 80, 80) -> (None, 12, 40, 40)
#
#       (skip-2): Identity()
#       (block-2): ConvBlock
#       DefaultBlock
#         layout=cnacna
#           Layer 0,  letter "c": (None, 12, 40, 40) -> (None, 24, 40, 40)
#           Layer 1,  letter "n": (None, 24, 40, 40) -> (None, 24, 40, 40)
#           Layer 2,  letter "a": (None, 24, 40, 40) -> (None, 24, 40, 40)
#           Layer 3,  letter "c": (None, 24, 40, 40) -> (None, 24, 40, 40)
#           Layer 4,  letter "n": (None, 24, 40, 40) -> (None, 24, 40, 40)
#           Layer 5,  letter "a": (None, 24, 40, 40) -> (None, 24, 40, 40)
#
#       (downsample-2): ConvBlock
#       layout=p
#         Layer 0,  letter "p": (None, 24, 40, 40) -> (None, 24, 20, 20)
#
#       (skip-3): Identity()
#       (block-3): ConvBlock
#       DefaultBlock
#         layout=cnacna
#           Layer 0,  letter "c": (None, 24, 20, 20) -> (None, 48, 20, 20)
#           Layer 1,  letter "n": (None, 48, 20, 20) -> (None, 48, 20, 20)
#           Layer 2,  letter "a": (None, 48, 20, 20) -> (None, 48, 20, 20)
#           Layer 3,  letter "c": (None, 48, 20, 20) -> (None, 48, 20, 20)
#           Layer 4,  letter "n": (None, 48, 20, 20) -> (None, 48, 20, 20)
#           Layer 5,  letter "a": (None, 48, 20, 20) -> (None, 48, 20, 20)
#
#       (downsample-3): ConvBlock
#       layout=p
#         Layer 0,  letter "p": (None, 48, 20, 20) -> (None, 48, 10, 10)
#
#     )
#     (embedding): EmbeddingModule(
#       (embedding): ConvBlock
#       DefaultBlock
#         layout=cnacna
#           Layer 0,  letter "c": (None, 48, 10, 10) -> (None, 96, 10, 10)
#           Layer 1,  letter "n": (None, 96, 10, 10) -> (None, 96, 10, 10)
#           Layer 2,  letter "a": (None, 96, 10, 10) -> (None, 96, 10, 10)
#           Layer 3,  letter "c": (None, 96, 10, 10) -> (None, 48, 10, 10)
#           Layer 4,  letter "n": (None, 48, 10, 10) -> (None, 48, 10, 10)
#           Layer 5,  letter "a": (None, 48, 10, 10) -> (None, 48, 10, 10)
#
#     )
#     (decoder): DecoderModule(
#       (upsample-0): Upsample(
#         (layer): ConvBlock
#         layout=tna
#           Layer 0,  letter "t": (None, 48, 10, 10) -> (None, 24, 20, 20)
#           Layer 1,  letter "n": (None, 24, 20, 20) -> (None, 24, 20, 20)
#           Layer 2,  letter "a": (None, 24, 20, 20) -> (None, 24, 20, 20)
#
#       )
#       (combine-0): Combine(
#         op=concat,
#         leading_idx=1,
#         input_shapes=[[(2, 24, 20, 20), (2, 24, 20, 20)]],
#         resized_shapes=[[(2, 24, 20, 20), (2, 24, 20, 20)]],
#         output_shape=(2, 48, 20, 20)
#       )
#       (block-0): ConvBlock
#       DefaultBlock
#         layout=cnacna
#           Layer 0,  letter "c": (None, 48, 20, 20) -> (None, 24, 20, 20)
#           Layer 1,  letter "n": (None, 24, 20, 20) -> (None, 24, 20, 20)
#           Layer 2,  letter "a": (None, 24, 20, 20) -> (None, 24, 20, 20)
#           Layer 3,  letter "c": (None, 24, 20, 20) -> (None, 24, 20, 20)
#           Layer 4,  letter "n": (None, 24, 20, 20) -> (None, 24, 20, 20)
#           Layer 5,  letter "a": (None, 24, 20, 20) -> (None, 24, 20, 20)
#
#       (upsample-1): Upsample(
#         (layer): ConvBlock
#         layout=tna
#           Layer 0,  letter "t": (None, 24, 20, 20) -> (None, 12, 40, 40)
#           Layer 1,  letter "n": (None, 12, 40, 40) -> (None, 12, 40, 40)
#           Layer 2,  letter "a": (None, 12, 40, 40) -> (None, 12, 40, 40)
#
#       )
#       (combine-1): Combine(
#         op=concat,
#         leading_idx=1,
#         input_shapes=[[(2, 12, 40, 40), (2, 12, 40, 40)]],
#         resized_shapes=[[(2, 12, 40, 40), (2, 12, 40, 40)]],
#         output_shape=(2, 24, 40, 40)
#       )
#       (block-1): ConvBlock
#       DefaultBlock
#         layout=cnacna
#           Layer 0,  letter "c": (None, 24, 40, 40) -> (None, 12, 40, 40)
#           Layer 1,  letter "n": (None, 12, 40, 40) -> (None, 12, 40, 40)
#           Layer 2,  letter "a": (None, 12, 40, 40) -> (None, 12, 40, 40)
#           Layer 3,  letter "c": (None, 12, 40, 40) -> (None, 12, 40, 40)
#           Layer 4,  letter "n": (None, 12, 40, 40) -> (None, 12, 40, 40)
#           Layer 5,  letter "a": (None, 12, 40, 40) -> (None, 12, 40, 40)
#
#       (upsample-2): Upsample(
#         (layer): ConvBlock
#         layout=tna
#           Layer 0,  letter "t": (None, 12, 40, 40) -> (None, 6, 80, 80)
#           Layer 1,  letter "n": (None, 6, 80, 80) -> (None, 6, 80, 80)
#           Layer 2,  letter "a": (None, 6, 80, 80) -> (None, 6, 80, 80)
#
#       )
#       (combine-2): Combine(
#         op=concat,
#         leading_idx=1,
#         input_shapes=[[(2, 6, 80, 80), (2, 6, 80, 80)]],
#         resized_shapes=[[(2, 6, 80, 80), (2, 6, 80, 80)]],
#         output_shape=(2, 12, 80, 80)
#       )
#       (block-2): ConvBlock
#       DefaultBlock
#         layout=cnacna
#           Layer 0,  letter "c": (None, 12, 80, 80) -> (None, 6, 80, 80)
#           Layer 1,  letter "n": (None, 6, 80, 80) -> (None, 6, 80, 80)
#           Layer 2,  letter "a": (None, 6, 80, 80) -> (None, 6, 80, 80)
#           Layer 3,  letter "c": (None, 6, 80, 80) -> (None, 6, 80, 80)
#           Layer 4,  letter "n": (None, 6, 80, 80) -> (None, 6, 80, 80)
#           Layer 5,  letter "a": (None, 6, 80, 80) -> (None, 6, 80, 80)
#
#       (upsample-3): Upsample(
#         (layer): ConvBlock
#         layout=tna
#           Layer 0,  letter "t": (None, 6, 80, 80) -> (None, 3, 160, 160)
#           Layer 1,  letter "n": (None, 3, 160, 160) -> (None, 3, 160, 160)
#           Layer 2,  letter "a": (None, 3, 160, 160) -> (None, 3, 160, 160)
#
#       )
#       (combine-3): Combine(
#         op=concat,
#         leading_idx=1,
#         input_shapes=[[(2, 3, 160, 160), (2, 3, 160, 160)]],
#         resized_shapes=[[(2, 3, 160, 160), (2, 3, 160, 160)]],
#         output_shape=(2, 6, 160, 160)
#       )
#       (block-3): ConvBlock
#       DefaultBlock
#         layout=cnacna
#           Layer 0,  letter "c": (None, 6, 160, 160) -> (None, 3, 160, 160)
#           Layer 1,  letter "n": (None, 3, 160, 160) -> (None, 3, 160, 160)
#           Layer 2,  letter "a": (None, 3, 160, 160) -> (None, 3, 160, 160)
#           Layer 3,  letter "c": (None, 3, 160, 160) -> (None, 3, 160, 160)
#           Layer 4,  letter "n": (None, 3, 160, 160) -> (None, 3, 160, 160)
#           Layer 5,  letter "a": (None, 3, 160, 160) -> (None, 3, 160, 160)
#
#     )
#   )
#   (head): Sequential(
#     (0): ConvBlock
#     layout=c
#       Layer 0,  letter "c": (None, 3, 160, 160) -> (None, 22, 160, 160)
#
#   )
# )

# %%
def process_mask(x):
    """ Background label is 255 and must be transformed to 21
    to make labels sequential. """
    x = np.squeeze(x)
    np.place(x, x==255, 21)
    return x

train_pipeline = (dataset.train.p
    .init_variable('loss_history', [])
    .init_model('dynamic', EncoderDecoder, 'model', config=model_config)
    .resize(size=IMAGE_SHAPE, src=['images', 'labels'], dst=['images', 'labels'])
    .to_array(channels='first', src=['images', 'labels'], dst=['images', 'labels'])
    .process_mask(B('labels'), save_to=B('labels'))
    .train_model('model', B('images'), B('labels'),
                fetches='loss', save_to=V('loss_history', mode='a'), use_lock=True)
)

# %%
train_pipeline.run(64, n_epochs=100, shuffle=True,
                   bar={'bar': 'n', 'frequency': 10,
                        'graphs': 'loss_history'})

# %%
pipeline = (dataset.test.p
                .import_model('model', train_pipeline)
                .init_variable('metrics')
                .init_variable('predictions')
                .resize(size=IMAGE_SHAPE, src=['images', 'labels'], dst=['images', 'labels'])
                .to_array(channels='first', src=['images', 'labels'], dst=['images', 'labels'])
                .process_mask(B('labels'), save_to=B('labels'))                
                .predict_model('model', B('images'), fetches='predictions',
                               save_to=V('predictions'))
                .gather_metrics('classification', B('labels'), V('predictions'),
                                 axis=1, fmt='logits', num_classes=num_classes,
                                 save_to=V('metrics', mode='update'))
            )

# %%
pipeline.run(32, drop_last=False, bar='n')
# Out:
#   0%|                                                                                                         …

# %%
f1_scores = pipeline.v('metrics').evaluate('f1_score', agg='mean', multiclass=None)
# Out:
# /notebooks/sorokina/batchflow/batchflow/models/metrics/classify.py:343: RuntimeWarning: invalid value encountered in true_divide
#   return 2 * (recall * precision) / (recall + precision)

# %%
f1_scores
# Out:
# array([0.78689198, 0.9378882 , 0.94616977, 0.92891649, 0.95031056,
#        0.93374741, 0.9489303 , 0.91235335, 0.9178744 , 0.91511387,
#        0.95100069, 0.94824017, 0.91166322, 0.94547964, 0.94755003,
#        0.09476372, 0.94133885, 0.96066253, 0.9378882 , 0.94202899,
#        0.9489303 , 0.03968625])

# %%
batch = pipeline.next_batch(3)
outputs = pipeline.v('predictions')[:3]

# %%
fig, axs = plt.subplots(nrows=3, ncols=3, figsize=(8, 8), subplot_kw={'xticks': [], 'yticks': []})

for picture_num, ax in enumerate(axs.flat):
    if picture_num<3:        
        ax.imshow(np.moveaxis(batch.images[picture_num] / 255, 0, -1))
    elif picture_num < 6:
        ax.imshow(batch.labels[picture_num-3])
    else:
        ax.imshow(np.argmax(outputs[picture_num-6], axis=0))


plt.tight_layout()
plt.show()
